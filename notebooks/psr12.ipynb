# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("diamonds")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.isna()
# Out:
#        carat    cut  color  clarity  depth  table  price      x      y      z
# 0      False  False  False    False  False  False  False  False  False  False
# 1      False  False  False    False  False  False  False  False  False  False
# 2      False  False  False    False  False  False  False  False  False  False
# 3      False  False  False    False  False  False  False  False  False  False
# 4      False  False  False    False  False  False  False  False  False  False
# ...      ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 53935  False  False  False    False  False  False  False  False  False  False
# 53936  False  False  False    False  False  False  False  False  False  False
# 53937  False  False  False    False  False  False  False  False  False  False
# 53938  False  False  False    False  False  False  False  False  False  False
# 53939  False  False  False    False  False  False  False  False  False  False
#
# [53940 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
df['carat'].hist()
# Out:
# <Axes: >

# %%
df['price'].hist(bins=20)
# Out:
# <Axes: >

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df['color'].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
df['clarity'].value_counts(normalize=True) * 100
# Out:
# clarity
# SI1     24.221357
# VS2     22.725250
# SI2     17.044865
# VS1     15.148313
# VVS2     9.391917
# VVS1     6.776047
# IF       3.318502
# I1       1.373749
# Name: proportion, dtype: float64

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df['cut'] == 'Ideal'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935     True
# 53936    False
# 53937    False
# 53938    False
# 53939     True
# Name: cut, Length: 53940, dtype: bool

# %%
selection = (df['cut'] == 'Ideal')
selection
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935     True
# 53936    False
# 53937    False
# 53938    False
# 53939     True
# Name: cut, Length: 53940, dtype: bool

# %%
ideal_diamonds = df[selection]

# %%
ideal_diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21551 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    21551 non-null  float64
#  1   cut      21551 non-null  category
#  2   color    21551 non-null  category
#  3   clarity  21551 non-null  category
#  4   depth    21551 non-null  float64
#  5   table    21551 non-null  float64
#  6   price    21551 non-null  int64
#  7   x        21551 non-null  float64
#  8   y        21551 non-null  float64
#  9   z        21551 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 1.4 MB

# %%
ideal_diamonds.price.hist()
# Out:
# <Axes: >

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# only premium cuts of color E
sel = (df.cut == 'Premium') & (df.color == 'E')
df[sel]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 53      0.22  Premium     E     VS2   61.6   58.0    404  3.93  3.89  2.41
# 69      0.24  Premium     E    VVS1   60.7   58.0    553  4.01  4.03  2.44
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53905   0.70  Premium     E     SI1   60.0   59.0   2753  5.75  5.79  3.46
# 53910   0.70  Premium     E     SI1   60.5   58.0   2753  5.74  5.77  3.48
# 53911   0.57  Premium     E      IF   59.8   60.0   2753  5.43  5.38  3.23
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
#
# [2337 rows x 10 columns]

# %%
# only Premium or Ideal cuts
sel = (df.cut == 'Premium') | (df.cut == 'Ideal')
df[sel]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [35342 rows x 10 columns]

# %% [markdown]
# Select dimonds that are:
#
# 1. Both larger than 1 carat and more expensive than 10,000$
#
# 2. Only 'Fair' cuts
#
# 3. Cheaper than 1000$ but only 'Ideal' cut.

# %%
task1 = (df.carat > 1) & (df.price > 10000)
df[task1]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 21928   1.70      Ideal     J     VS2   60.5   58.0  10002  7.73  7.74  4.68
# 21929   1.03      Ideal     E    VVS2   60.6   59.0  10003  6.50  6.53  3.95
# 21930   1.23  Very Good     G    VVS2   60.6   55.0  10004  6.93  7.02  4.23
# 21931   1.25      Ideal     F     VS2   61.6   55.0  10006  6.93  6.96  4.28
# 21932   2.01  Very Good     I     SI2   61.4   63.0  10009  8.19  7.96  4.96
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# [5205 rows x 10 columns]

# %%
task2 = (df.cut == "Fair")
df[task2]
# Out:
#        carat   cut color clarity  depth  table  price     x     y     z
# 8       0.22  Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 91      0.86  Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 97      0.96  Fair     F     SI2   66.3   62.0   2759  6.27  5.95  4.07
# 123     0.70  Fair     F     VS2   64.5   57.0   2762  5.57  5.53  3.58
# 124     0.70  Fair     F     VS2   65.3   55.0   2762  5.63  5.58  3.66
# ...      ...   ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53757   0.72  Fair     F     VS2   55.4   64.0   2724  6.06  5.97  3.34
# 53800   0.90  Fair     I     VS1   68.7   62.0   2732  5.83  5.79  3.99
# 53863   1.00  Fair     I     SI2   66.8   56.0   2743  6.22  6.12  4.13
# 53879   1.04  Fair     G     SI2   65.2   57.0   2745  6.25  6.23  4.07
# 53882   0.71  Fair     D     VS1   65.4   59.0   2747  5.62  5.58  3.66
#
# [1610 rows x 10 columns]

# %%
task3 = (df.price < 1000) & (df.cut == 'Ideal')
df.loc[task3, ['price', 'x']]
# Out:
#        price     x
# 0        326  3.95
# 11       340  3.93
# 13       344  4.35
# 16       348  4.31
# 39       403  4.49
# ...      ...   ...
# 53634    552  4.30
# 53635    552  4.30
# 53636    552  4.28
# 53638    552  4.29
# 53639    552  4.35
#
# [6838 rows x 2 columns]

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.price.mean()
# Out:
# np.float64(3932.799721913237)

# %%
df[df.color == 'I'].price.mean()
# Out:
# np.float64(5091.874953891553)

# %%
df[df.color == 'D'].price.mean()
# Out:
# np.float64(3169.9540959409596)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.groupby('color')
# Out:
# <ipython-input-46-3ab25a93b883>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('color')

# %%
df.groupby('color').price.mean()
# Out:
# <ipython-input-47-dc0364f4881a>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('color').price.mean()
# color
# D    3169.954096
# E    3076.752475
# F    3724.886397
# G    3999.135671
# H    4486.669196
# I    5091.874954
# J    5323.818020
# Name: price, dtype: float64

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.groupby('color').carat.describe()
# Out:
# <ipython-input-50-f70b2e69cdcd>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('color').carat.describe()
#          count      mean       std   min   25%   50%    75%   max
# color
# D       6775.0  0.657795  0.359573  0.20  0.36  0.53  0.905  3.40
# E       9797.0  0.657867  0.368566  0.20  0.36  0.53  0.900  3.05
# F       9542.0  0.736538  0.397588  0.20  0.40  0.70  1.010  3.01
# G      11292.0  0.771190  0.441436  0.23  0.39  0.70  1.040  3.01
# H       8304.0  0.911799  0.521236  0.23  0.41  0.90  1.200  4.13
# I       5422.0  1.026927  0.579173  0.23  0.52  1.00  1.500  4.01
# J       2808.0  1.162137  0.595801  0.23  0.71  1.11  1.520  5.01

# %%
df.groupby('color').price.describe().round(2)
# Out:
# <ipython-input-55-f9bffeca041d>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('color').price.describe().round(2)
#          count     mean      std    min     25%     50%      75%      max
# color
# D       6775.0  3169.95  3356.59  357.0   911.0  1838.0  4213.50  18693.0
# E       9797.0  3076.75  3344.16  326.0   882.0  1739.0  4003.00  18731.0
# F       9542.0  3724.89  3784.99  342.0   982.0  2343.5  4868.25  18791.0
# G      11292.0  3999.14  4051.10  354.0   931.0  2242.0  6048.00  18818.0
# H       8304.0  4486.67  4215.94  337.0   984.0  3460.0  5980.25  18803.0
# I       5422.0  5091.87  4722.39  334.0  1120.5  3730.0  7201.75  18823.0
# J       2808.0  5323.82  4438.19  335.0  1860.5  4234.0  7695.00  18710.0

# %%
round(df.price.std(), 2)
# Out:
# 3989.44

# %%
sorted_df = df.sort_values(by='price', ascending=False)
sorted_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
#
# [53940 rows x 10 columns]

# %%
sorted_df.iloc[:10, :]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27744   2.29    Premium     I     SI1   61.8   59.0  18797  8.52  8.45  5.24
# 27742   2.04    Premium     H     SI1   58.1   60.0  18795  8.37  8.28  4.84
# 27743   2.00    Premium     I     VS1   60.8   59.0  18795  8.13  8.02  4.91
# 27741   2.15      Ideal     G     SI2   62.6   54.0  18791  8.29  8.35  5.21
# 27740   1.71    Premium     F     VS2   62.3   59.0  18791  7.57  7.53  4.70

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.scatterplot(data=df, x='carat', y='price', marker='.', alpha=.5)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(df, x='cut', y='price', kind='violin')

# %%
sns.catplot(df, x='cut', y='carat', kind='violin')

# %%
sns.displot(df, x='price', kind='kde', hue='cut')
