# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.catplot(data=df, x='species', y='petal_length')

# %%
sns.catplot(data=df, x='species', y='petal_length', kind='swarm')

# %%
diamonds = sns.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(data=diamonds, x='cut', y='price', kind='swarm')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d323c672d1f2> in <cell line: 0>()
# ----> 1 sns.catplot(data=diamonds, x='cut', y='price', kind='swarm')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2895             plot_kws["linewidth"] = np.sqrt(plot_kws["s"]) / 10
#    2896
# -> 2897         p.plot_swarms(
#    2898             dodge=dodge,
#    2899             color=color,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in plot_swarms(self, dodge, color, warn_thresh, plot_kws)
# ...

# %%
sns.catplot(data=diamonds[:500], x='cut', y='price', kind='swarm')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 72.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 70.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 57.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 25.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(data=df, x='species', y='petal_length', kind='box')

# %%
sns.catplot(data=df, x='species', y='petal_length', kind='violin')

# %%
sns.catplot(data=df, y='species', x='petal_length', kind='violin')

# %%
sns.catplot(data=diamonds, x='price', y='cut', kind='violin')

# %%
sns.catplot(data=df, x='species', y='petal_length', kind='boxen')

# %%
sns.catplot(data=diamonds, x='price', y='cut', kind='boxen')

# %%
sns.catplot(data=df, x='species', y='petal_length', kind='point')

# %%
sns.catplot(data=diamonds, x='color', y='price', hue='cut', kind='point')

# %%
sns.catplot(data=diamonds, x='cut', y='price', hue='color', kind='point')

# %%
sns.catplot(data=df, x='species', y='petal_length', kind='bar')

# %%
sns.catplot(data=diamonds, x='cut', y='price', hue='color', kind='bar')

# %%
sns.catplot(data=df, x='species', kind='count')

# %%
sns.catplot(data=diamonds, x='cut', hue='color', kind='count')

# %%
sns.displot(data=diamonds, x='price', hue='color', kind='kde')

# %%
sns.displot(data=diamonds, x='price', hue='color', kind='kde', cumulative=True)

# %%
sns.displot(data=diamonds, x='price', hue='color', kind='kde', fill=True, alpha=.2)
plt.xlabel('Price ($)')

plt.savefig('fig2.png', dpi=300)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.kdeplot(data=diamonds, x='price', hue='color', ax=axs[0])
sns.kdeplot(data=diamonds, x='carat', hue='color', ax=axs[1])

plt.savefig('fig3.png', dpi=300)

# %%
diamonds.cut.value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
sns.displot(data=df, x='petal_width', y='petal_length', fill=True, kind='kde')

# %%
sns.displot(data=df, x='sepal_length', y='petal_length', fill=True, kind='kde')

# %%
sns.displot(data=df, x='sepal_length', y='petal_length', hue='species', fill=True, kind='kde')

# %%
sns.displot(data=diamonds, x='price', hue='color', kind='kde', fill=True, alpha=.2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.petal_length, df.sepal_length)
plt.savefig('fig1.png', dpi=300)
