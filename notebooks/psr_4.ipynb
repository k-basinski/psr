# %%
2+2
# Out:
# 4

# %%
s = "This is a nice string of characters."

# %%
s
# Out:
# 'This is a nice string of characters.'

# %%
s[0]
# Out:
# 'T'

# %%
s[1]
# Out:
# 'h'

# %%
s[-1]
# Out:
# '.'

# %%
s[1:4]
# Out:
# 'his'

# %%
s[4:7]
# Out:
# ' is'

# %%
s[7:10]
# Out:
# ' a '

# %%
s[:10]
# Out:
# 'This is a '

# %%
s[10:]
# Out:
# 'nice string of characters.'

# %%
i = 15
print(s[:i])
print(s[i:])
# Out:
# This is a nice
# string of characters.

# %%
s[10:1:-1]
# Out:
# 'n a si si'

# %% [markdown]
# ## Iterables
#
# Smth that can be **iterated**.

# %%
fruit = ['banana', 'apple', 'pear', 'orange', 'plum']

# %%
type(fruit)
# Out:
# list

# %%
# length of the list
len(fruit)
# Out:
# 5

# %%
fruit[0]
# Out:
# 'banana'

# %%
type(fruit[0])
# Out:
# str

# %%
fruit[3]
# Out:
# 'orange'

# %%
fruit[-1]
# Out:
# 'plum'

# %%
fruit[:3]
# Out:
# ['banana', 'apple', 'pear']

# %%
fruit[-3:]
# Out:
# ['pear', 'orange', 'plum']

# %%
# reverse the order of elements

# %%
fruit.reverse()

# %%
fruit
# Out:
# ['banana', 'apple', 'pear', 'orange', 'plum']

# %%
fruit[::-1]
# Out:
# ['plum', 'orange', 'pear', 'apple', 'banana']

# %%
s[::-1]
# Out:
# '.sretcarahc fo gnirts ecin a si sihT'

# %%
fruit = ['banana', 'apple', 'pear', 'orange', 'plum']
print("The original: ", fruit)
print("Reverse with slicing:", fruit[::-1])
print("Now, the list is:", fruit)
# now reverse()
fruit.reverse() # this reverses the list IN PLACE
print("After .reverse()", fruit)
# Out:
# The original:  ['banana', 'apple', 'pear', 'orange', 'plum']
# Reverse with slicing: ['plum', 'orange', 'pear', 'apple', 'banana']
# Now, the list is: ['banana', 'apple', 'pear', 'orange', 'plum']
# After .reverse() ['plum', 'orange', 'pear', 'apple', 'banana']

# %%
fruit
# Out:
# ['plum', 'orange', 'pear', 'apple', 'banana']

# %% [markdown]
# ## Lists in Python are MUTABLE
#
# You can change them after they're created.

# %%
len(fruit) # a function
fruit.append('grape') # a method of 'fruit' (or a list method)

# %%
fruit
# Out:
# ['plum', 'orange', 'pear', 'apple', 'banana', 'grape', 'grape', 'grape']

# %%
fruit.remove('plum')

# %%
fruit
# Out:
# ['orange', 'pear', 'apple', 'banana', 'grape', 'grape', 'grape']

# %%
fruit.pop(3)
fruit
# Out:
# ['orange', 'pear', 'apple', 'grape', 'grape', 'grape']

# %%
fruit.count('grape')
# Out:
# 3

# %%
fruit.count('potato')
# Out:
# 0

# %%
fruit.index('grape')
# Out:
# 3

# %%
fruit.index('potato')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-86920fe76cbf> in <cell line: 0>()
# ----> 1 fruit.index('potato')
#
# ValueError: 'potato' is not in list

# %%
fruit.sort()

# %%
fruit
# Out:
# ['apple', 'grape', 'grape', 'grape', 'orange', 'pear']

# %%
fruit.sort(reverse=True)

# %%
fruit
# Out:
# ['pear', 'orange', 'grape', 'grape', 'grape', 'apple']

# %%
# extend method
a = [1, 2, 3]
b = [4, 5, 6]
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
b
# Out:
# [4, 5, 6]

# %%
s
# Out:
# 'This is a nice string of characters.'

# %%
s.upper()
# Out:
# 'THIS IS A NICE STRING OF CHARACTERS.'

# %%
s.lower()
# Out:
# 'this is a nice string of characters.'

# %%
s
# Out:
# 'This is a nice string of characters.'

# %%
"blablabla".upper()
# Out:
# 'BLABLABLA'

# %%
[1, 1.2, 'sharaefaef', True]
# Out:
# [1, 1.2, 'sharaefaef', True]

# %%
# a list of lists
ll = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
type(ll)
# Out:
# list

# %%
len(ll)
# Out:
# 3

# %%
ll[0]
# Out:
# [1, 2, 3]

# %%
ll[1]
# Out:
# [4, 5, 6]

# %%
ll[2]
# Out:
# [7, 8, 9]

# %%
ll[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-e378e9714d7c> in <cell line: 0>()
# ----> 1 ll[3]
#
# IndexError: list index out of range

# %%
len(ll[0])
# Out:
# 3

# %%
ll[0][0]
# Out:
# 1

# %%
ll
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
ll[2][1]
# Out:
# 8

# %% [markdown]
# ## Tuples
#
# Similar to lists, except NON-MUTABLE

# %%
(a, b) = (1, 3)

# %%
a
# Out:
# 1

# %%
b
# Out:
# 3

# %%
type((a, b))
# Out:
# tuple

# %%
type((1,3))
# Out:
# tuple

# %%
[a, b] = [4.5, 3.]

# %%
a
# Out:
# 4.5

# %%
t = (1, 2, 3, 4, 5)

# %%
t[2]
# Out:
# 3

# %%
t[:3]
# Out:
# (1, 2, 3)

# %%
type(t[3:])
# Out:
# tuple

# %%
t[4] = 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-d858fbde7374> in <cell line: 0>()
# ----> 1 t[4] = 123
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[5] = 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-d914518f2d2d> in <cell line: 0>()
# ----> 1 t[5] = 123
#
# TypeError: 'tuple' object does not support item assignment

# %%
type((1,2,3,))
# Out:
# tuple

# %%
f = open("text.txt", mode="r")

# %%
f
# Out:
# <_io.TextIOWrapper name='text.txt' mode='r' encoding='UTF-8'>

# %%
file_text = f.readlines()
file_text
# Out:
# ['This is a text file\n',
#  "It's pretty nice\n",
#  '\n',
#  '\n',
#  '\n',
#  'It contains nothing important\n',
#  'Blalbalba.\n',
#  'Can I edit ? Nice.']

# %%
f.close()

# %%
print("This is nice text. Try new lines! \n\n\n\nThis is smth else.")
# Out:
# This is nice text. Try new lines!
#
#
#
# This is smth else.

# %%
print("\\n")
# Out:
# \n

# %%
with open('text.txt') as f:
  lines_f = f.read()
  lines = lines_f.splitlines()

# this doesn't require closing

# %%
lines_f
# Out:
# "This is a text file\nIt's pretty nice\n\n\n\nIt contains nothing important\nBlalbalba.\nCan I edit ? Nice."

# %%
lines
# Out:
# ['This is a text file',
#  "It's pretty nice",
#  '',
#  '',
#  '',
#  'It contains nothing important',
#  'Blalbalba.',
#  'Can I edit ? Nice.']
