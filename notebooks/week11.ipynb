# %%
import pandas as pd

# %%
df = pd.read_excel('ppl.xlsx')

# %%
df
# Out:
#     id gender  height
# 0    1      m     175
# 1    2      m     175
# 2    3      m     177
# 3    4      m     179
# 4    5      m     199
# 5    6      m     167
# 6    7      m     188
# 7    8      m     177
# 8    9      m     177
# 9   10      m     179
# 10  11      m     199
# 11  12      m     167
# 12  13      m     188
# 13  14     mm     177
# 14  15      m     177
# 15  16      f     179
# 16  17      f     199
# 17  18      f     167
# 18  19      f     188
# 19  20      f     177
# 20  21      f     150
# 21  22      f     155
# 22  23      f     166
# 23  24      f     170
# 24  25      f     168
# 25  26      f     170
# 26  27      f     165
# 27  28      f     170
# 28  29      f    1668
# 29  30      f     170

# %%
df['gender']
# Out:
# 0      m
# 1      m
# 2      m
# 3      m
# 4      m
# 5      m
# 6      m
# 7      m
# 8      m
# 9      m
# 10     m
# 11     m
# 12     m
# 13    mm
# 14     m
# 15     f
# 16     f
# 17     f
# 18     f
# 19     f
# 20     f
# 21     f
# 22     f
# 23     f
# 24     f
# 25     f
# 26     f
# 27     f
# 28     f
# 29     f
# Name: gender, dtype: object

# %%
df['gender'].value_counts()
# Out:
# f     15
# m     14
# mm     1
# Name: gender, dtype: int64

# %%
df['gender'] == 'mm'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: gender, dtype: bool

# %%
df.gender
# Out:
# 0      m
# 1      m
# 2      m
# 3      m
# 4      m
# 5      m
# 6      m
# 7      m
# 8      m
# 9      m
# 10     m
# 11     m
# 12     m
# 13    mm
# 14     m
# 15     f
# 16     f
# 17     f
# 18     f
# 19     f
# 20     f
# 21     f
# 22     f
# 23     f
# 24     f
# 25     f
# 26     f
# 27     f
# 28     f
# 29     f
# Name: gender, dtype: object

# %%
df.gender == 'mm'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: gender, dtype: bool

# %%
df.loc[df.gender == 'mm', 'gender']
# Out:
# 13    mm
# Name: gender, dtype: object

# %%
df.loc[df.gender == 'mm', :]
# Out:
#     id gender  height
# 13  14     mm     177

# %%
df.loc[df.gender != 'mm', 'gender']
# Out:
# 0     m
# 1     m
# 2     m
# 3     m
# 4     m
# 5     m
# 6     m
# 7     m
# 8     m
# 9     m
# 10    m
# 11    m
# 12    m
# 14    m
# 15    f
# 16    f
# 17    f
# 18    f
# 19    f
# 20    f
# 21    f
# 22    f
# 23    f
# 24    f
# 25    f
# 26    f
# 27    f
# 28    f
# 29    f
# Name: gender, dtype: object

# %%
sel = ((df.gender == 'mm') | (df.gender == 'm'))

# %%
sel
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: gender, dtype: bool

# %%
df.loc[sel, :]
# Out:
#     id gender  height
# 0    1      m     175
# 1    2      m     175
# 2    3      m     177
# 3    4      m     179
# 4    5      m     199
# 5    6      m     167
# 6    7      m     188
# 7    8      m     177
# 8    9      m     177
# 9   10      m     179
# 10  11      m     199
# 11  12      m     167
# 12  13      m     188
# 13  14     mm     177
# 14  15      m     177

# %%
a = 3
a
# Out:
# 3

# %%
a = 4

# %%
a
# Out:
# 4

# %%
df.loc[(df.gender == 'mm'), 'gender']
# Out:
# 13    mm
# Name: gender, dtype: object

# %%
df.loc[(df.gender == 'mm'), 'gender'] = 'm'

# %%
df
# Out:
#     id gender  height
# 0    1      m     175
# 1    2      m     175
# 2    3      m     177
# 3    4      m     179
# 4    5      m     199
# 5    6      m     167
# 6    7      m     188
# 7    8      m     177
# 8    9      m     177
# 9   10      m     179
# 10  11      m     199
# 11  12      m     167
# 12  13      m     188
# 13  14      m     177
# 14  15      m     177
# 15  16      f     179
# 16  17      f     199
# 17  18      f     167
# 18  19      f     188
# 19  20      f     177
# 20  21      f     150
# 21  22      f     155
# 22  23      f     166
# 23  24      f     170
# 24  25      f     168
# 25  26      f     170
# 26  27      f     165
# 27  28      f     170
# 28  29      f    1668
# 29  30      f     170

# %%
df.gender.value_counts()
# Out:
# m    15
# f    15
# Name: gender, dtype: int64

# %%
df.loc[1, 'gender']
# Out:
# 'm'

# %%
df.loc[5:10, 'height']
# Out:
# 5     167
# 6     188
# 7     177
# 8     177
# 9     179
# 10    199
# Name: height, dtype: int64

# %%
# Show me all ppl that are over 180 cm in height.

# %%
df.loc[(df.height > 180)]
# Out:
#     id gender  height
# 4    5      m     199
# 6    7      m     188
# 10  11      m     199
# 12  13      m     188
# 16  17      f     199
# 18  19      f     188
# 28  29      f    1668

# %%
sel = (df.height > 180)
sel
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# Name: height, dtype: bool

# %%
df.loc[sel]
# Out:
#     id gender  height
# 4    5      m     199
# 6    7      m     188
# 10  11      m     199
# 12  13      m     188
# 16  17      f     199
# 18  19      f     188
# 28  29      f    1668

# %%
df.loc[sel, ['gender', 'height']]
# Out:
#    gender  height
# 4       m     199
# 6       m     188
# 10      m     199
# 12      m     188
# 16      f     199
# 18      f     188
# 28      f    1668

# %%
df
# Out:
#     id gender  height
# 0    1      m     175
# 1    2      m     175
# 2    3      m     177
# 3    4      m     179
# 4    5      m     199
# 5    6      m     167
# 6    7      m     188
# 7    8      m     177
# 8    9      m     177
# 9   10      m     179
# 10  11      m     199
# 11  12      m     167
# 12  13      m     188
# 13  14      m     177
# 14  15      m     177
# 15  16      f     179
# 16  17      f     199
# 17  18      f     167
# 18  19      f     188
# 19  20      f     177
# 20  21      f     150
# 21  22      f     155
# 22  23      f     166
# 23  24      f     170
# 24  25      f     168
# 25  26      f     170
# 26  27      f     165
# 27  28      f     170
# 28  29      f    1668
# 29  30      f     170

# %%
df.height / 100
# Out:
# 0      1.75
# 1      1.75
# 2      1.77
# 3      1.79
# 4      1.99
# 5      1.67
# 6      1.88
# 7      1.77
# 8      1.77
# 9      1.79
# 10     1.99
# 11     1.67
# 12     1.88
# 13     1.77
# 14     1.77
# 15     1.79
# 16     1.99
# 17     1.67
# 18     1.88
# 19     1.77
# 20     1.50
# 21     1.55
# 22     1.66
# 23     1.70
# 24     1.68
# 25     1.70
# 26     1.65
# 27     1.70
# 28    16.68
# 29     1.70
# Name: height, dtype: float64

# %%
df['height_meters'] = df['height'] / 100

# %%
df
# Out:
#     id gender  height  height_meters
# 0    1      m     175           1.75
# 1    2      m     175           1.75
# 2    3      m     177           1.77
# 3    4      m     179           1.79
# 4    5      m     199           1.99
# 5    6      m     167           1.67
# 6    7      m     188           1.88
# 7    8      m     177           1.77
# 8    9      m     177           1.77
# 9   10      m     179           1.79
# 10  11      m     199           1.99
# 11  12      m     167           1.67
# 12  13      m     188           1.88
# 13  14      m     177           1.77
# 14  15      m     177           1.77
# 15  16      f     179           1.79
# 16  17      f     199           1.99
# 17  18      f     167           1.67
# 18  19      f     188           1.88
# 19  20      f     177           1.77
# 20  21      f     150           1.50
# 21  22      f     155           1.55
# 22  23      f     166           1.66
# 23  24      f     170           1.70
# ...

# %%
df.sort_values('height')
# Out:
#     id gender  height  height_meters
# 20  21      f     150           1.50
# 21  22      f     155           1.55
# 26  27      f     165           1.65
# 22  23      f     166           1.66
# 5    6      m     167           1.67
# 17  18      f     167           1.67
# 11  12      m     167           1.67
# 24  25      f     168           1.68
# 29  30      f     170           1.70
# 27  28      f     170           1.70
# 25  26      f     170           1.70
# 23  24      f     170           1.70
# 0    1      m     175           1.75
# 1    2      m     175           1.75
# 13  14      m     177           1.77
# 2    3      m     177           1.77
# 7    8      m     177           1.77
# 19  20      f     177           1.77
# 8    9      m     177           1.77
# 14  15      m     177           1.77
# 9   10      m     179           1.79
# 3    4      m     179           1.79
# 15  16      f     179           1.79
# 12  13      m     188           1.88
# ...

# %%
df.sort_values('height', ascending=False, inplace=True)

# %%
df
# Out:
#     id gender  height  height_meters
# 28  29      f    1668          16.68
# 16  17      f     199           1.99
# 4    5      m     199           1.99
# 10  11      m     199           1.99
# 6    7      m     188           1.88
# 12  13      m     188           1.88
# 18  19      f     188           1.88
# 15  16      f     179           1.79
# 3    4      m     179           1.79
# 9   10      m     179           1.79
# 2    3      m     177           1.77
# 7    8      m     177           1.77
# 8    9      m     177           1.77
# 19  20      f     177           1.77
# 13  14      m     177           1.77
# 14  15      m     177           1.77
# 0    1      m     175           1.75
# 1    2      m     175           1.75
# 23  24      f     170           1.70
# 25  26      f     170           1.70
# 27  28      f     170           1.70
# 29  30      f     170           1.70
# 24  25      f     168           1.68
# 17  18      f     167           1.67
# ...

# %%
df.height.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.displot(df, x='height')

# %%
df.loc[df.height > 200, :]
# Out:
#     id gender  height  height_meters
# 28  29      f    1668          16.68

# %%
df.loc[df.height > 200, 'height']
# Out:
# 28    1668
# Name: height, dtype: int64

# %%
import numpy as np

# %%
df.loc[df.height > 200, 'height'] = np.nan

# %%
df.height
# Out:
# 28      NaN
# 16    199.0
# 4     199.0
# 10    199.0
# 6     188.0
# 12    188.0
# 18    188.0
# 15    179.0
# 3     179.0
# 9     179.0
# 2     177.0
# 7     177.0
# 8     177.0
# 19    177.0
# 13    177.0
# 14    177.0
# 0     175.0
# 1     175.0
# 23    170.0
# 25    170.0
# 27    170.0
# 29    170.0
# 24    168.0
# 17    167.0
# 11    167.0
# 5     167.0
# 22    166.0
# 26    165.0
# 21    155.0
# 20    150.0
# Name: height, dtype: float64

# %%
sns.displot(df, x='height')

# %%
df.height.mean(skipna=True)
# Out:
# 175.68965517241378

# %%
np_height = df.height.to_numpy()
np_height.mean()
# Out:
# nan

# %% [markdown]
# Kernel density estimation (KDE)

# %%
sns.displot(df, x='height', kind='kde')

# %%
sns.displot(data=df, x='height', hue='gender', kind='kde')

# %%
sns.displot(data=df, y='height', hue='gender', kind='kde')
