# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('diamonds')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df.cut.value_counts(normalize=True) * 100
# Out:
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: cut, dtype: float64

# %%
df.cut.value_counts(dropna=False)
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
def vc(s):
  return s.value_counts(dropna=False)


vc(df.cut)
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.loc[df.cut == 'Ideal', 'price'].mean()
# Out:
# 3457.541970210199

# %%
df.loc[df.cut == 'Premium', 'price'].mean()
# Out:
# 4584.2577042999055

# %%
df.groupby('cut')

# %%
df.groupby('cut').price.mean()
# Out:
# cut
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Good         3928.864452
# Fair         4358.757764
# Name: price, dtype: float64

# %%
df.groupby('cut').price.describe().round(1)
# Out:
#              count    mean     std    min     25%     50%     75%      max
# cut
# Ideal      21551.0  3457.5  3808.4  326.0   878.0  1810.0  4678.5  18806.0
# Premium    13791.0  4584.3  4349.2  326.0  1046.0  3185.0  6296.0  18823.0
# Very Good  12082.0  3981.8  3935.9  336.0   912.0  2648.0  5372.8  18818.0
# Good        4906.0  3928.9  3681.6  327.0  1145.0  3050.5  5028.0  18788.0
# Fair        1610.0  4358.8  3560.4  337.0  2050.2  3282.0  5205.5  18574.0

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
result = df.groupby('clarity').price.describe()
result.loc[:, ['mean', 'std']].round(2)
# Out:
#             mean      std
# clarity
# IF       2864.84  3920.25
# VVS1     2523.11  3334.84
# VVS2     3283.74  3821.65
# VS1      3839.46  4011.75
# VS2      3924.99  4042.30
# SI1      3996.00  3799.48
# SI2      5063.03  4260.46
# I1       3924.17  2806.78

# %%
result.loc[:, ['mean', 'std']].round(2).to_excel('result.xlsx')

# %%
def binning(x):
  if x > 5000:
    return 'big'
  else:
    return 'small'

# %%
binning(.6)
# Out:
# 'big'

# %%
df.loc[df.carat.between(0.2, 0.3)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53635   0.30      Ideal     I    VVS1   62.1   56.0    552  4.30  4.33  2.68
# 53636   0.30      Ideal     D     SI1   61.6   57.0    552  4.28  4.32  2.65
# 53637   0.30  Very Good     D     SI1   62.5   57.0    552  4.26  4.28  2.67
# 53638   0.30      Ideal     D     SI1   61.0   57.0    552  4.29  4.33  2.63
# 53639   0.30      Ideal     D     SI1   61.0   56.0    552  4.35  4.37  2.66
#
# [4203 rows x 10 columns]

# %%
df.carat.between(0.2, 0.3)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Name: carat, Length: 53940, dtype: bool

# %%
sns.displot(data=df, x='price')

# %%
sns.displot(data=df, x='price', kind='kde')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(data=df, x='clarity', y='price', kind='box')

# %%
sns.catplot(data=df, x='clarity', y='price', kind='violin')

# %%
sns.displot(df, y='price', hue='clarity', kind='kde')

# %%
sns.relplot(df, x='price', y='carat', alpha=.1)

# %%
sns.relplot(df[3500:3600], x='price', y='carat', hue='clarity')

# %%
two_cat = df.loc[((df.clarity == 'SI1')| (df.clarity == 'SI2'))].copy()

# %%
two_cat.clarity.value_counts()
# Out:
# SI1     13065
# SI2      9194
# IF          0
# VVS1        0
# VVS2        0
# VS1         0
# VS2         0
# I1          0
# Name: clarity, dtype: int64

# %%
sns.catplot(two_cat, x='cut', y='price', hue='clarity', kind='violin', split=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-5b4a171c8bf3> in <cell line: 1>()
# ----> 1 sns.catplot(two_cat, x='cut', y='price', hue='clarity', kind='violin', split=True)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3242
#    3243     # Draw the plot onto the facets
# -> 3244     g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3245
#    3246     if p.orient == "h":
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     817
#     818             # Draw the plot
# ...
