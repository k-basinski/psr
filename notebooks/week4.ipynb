# %%
print ('hello')
# Out:
# hello

# %%
type(1)
# Out:
# int

# %%
type('hello')
# Out:
# str

# %%
type(1.23)
# Out:
# float

# %%
type(1) is int
# Out:
# True

# %%
type(1.2) is int
# Out:
# False

# %%
type('hello') is str
# Out:
# True

# %%
str
# Out:
# str

# %%
type('hello') == int
# Out:
# False

# %%
1 == int
# Out:
# False

# %%
type(1) == int
# Out:
# True

# %%
a = 'dog'
b = 'cat'

# %%
# LIST

my_list = ['dog', 'cat', 'parrot', 'elephant', 'badger']

# %%
type(my_list)
# Out:
# list

# %%
my_list[0]
# Out:
# 'dog'

# %%
my_list[1]
# Out:
# 'cat'

# %%
my_list
# Out:
# ['dog', 'cat', 'parrot', 'elephant', 'badger']

# %%
my_list[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-075ca585e721> in <module>
# ----> 1 my_list[5]
#
# IndexError: list index out of range

# %%
len(my_list)
# Out:
# 5

# %%
my_list[-1]
# Out:
# 'badger'

# %%
my_list[-2]
# Out:
# 'elephant'

# %%
my_list[-4]
# Out:
# 'cat'

# %%
my_list[3]
# Out:
# 'elephant'

# %%
my_list.append('squirrel')

# %%
my_list
# Out:
# ['dog', 'cat', 'parrot', 'elephant', 'badger', 'squirrel']

# %%
len(my_list)
# Out:
# 6

# %%
cars = ['skoda', 'audi', 'renault', 'bmw']

# %%
cars
# Out:
# ['skoda', 'audi', 'renault', 'bmw']

# %%
cars.append('mercedes')

# %%
cars
# Out:
# ['skoda', 'audi', 'renault', 'bmw', 'mercedes']

# %%
len(cars)
# Out:
# 5

# %%
cars.insert(1, 'citroen')

# %%
cars
# Out:
# ['skoda', 'citroen', 'audi', 'renault', 'bmw', 'mercedes']

# %%
cars.pop(3)
# Out:
# 'renault'

# %%
cars
# Out:
# ['skoda', 'citroen', 'audi', 'bmw', 'mercedes']

# %%
cars.append('audi')

# %%
cars
# Out:
# ['skoda', 'citroen', 'audi', 'bmw', 'mercedes', 'audi']

# %%
cars.remove('audi')

# %%
cars
# Out:
# ['skoda', 'citroen', 'bmw', 'mercedes', 'audi']

# %%
cars.remove('mazda')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-c97564d72f73> in <module>
# ----> 1 cars.remove('mazda')
#
# ValueError: list.remove(x): x not in list

# %%
cars.remove('bmw')

# %%
cars
# Out:
# ['skoda', 'citroen', 'mercedes', 'audi']

# %%
cars.append('audi')

# %%
cars.count('audi')
# Out:
# 2

# %%
cars.index('mercedes')
# Out:
# 2

# %%
cars
# Out:
# ['skoda', 'citroen', 'mercedes', 'audi', 'audi']

# %%
cars.sort()

# %%
cars
# Out:
# ['audi', 'audi', 'citroen', 'mercedes', 'skoda']

# %%
a = [1, 4, 3, 2, 5, 4, 4.44]
a.sort()
a
# Out:
# [1, 2, 3, 4, 4, 4.44, 5]

# %%
a[4.4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-120d9fb08fe2> in <module>
# ----> 1 a[4.4]
#
# TypeError: list indices must be integers or slices, not float

# %%
a[3 + 1]
# Out:
# 4

# %%
i = 5
a[i]
# Out:
# 4.44

# %%
a[float]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-e0e38f4d4da5> in <module>
# ----> 1 a[float]
#
# TypeError: list indices must be integers or slices, not type

# %%
cars
# Out:
# ['audi', 'audi', 'citroen', 'mercedes', 'skoda']

# %%
cars.insert(1,'bmw')
cars.insert(4,'toyota')

# %%
cars
# Out:
# ['audi', 'bmw', 'audi', 'citroen', 'toyota', 'mercedes', 'skoda']

# %%
len(cars)
# Out:
# 7

# %%
cars[1:4]
# Out:
# ['bmw', 'audi', 'citroen']

# %%
cars[0:2]
# Out:
# ['audi', 'bmw']

# %%
i = 3
cars[i:i+2]
# Out:
# ['citroen', 'toyota']

# %%
cars[:3]
# Out:
# ['audi', 'bmw', 'audi']

# %%
cars[5:]
# Out:
# ['mercedes', 'skoda']

# %%
cars[0:2]
# Out:
# ['audi', 'bmw']

# %%
cars[2:4]
# Out:
# ['audi', 'citroen']

# %%
cars[4:6]
# Out:
# ['toyota', 'mercedes']

# %%
cars[6:8]
# Out:
# ['skoda']

# %%
i = 5
cars[i:i+2]
# Out:
# ['mercedes', 'skoda']

# %%
cars[-1]
# Out:
# 'skoda'

# %%
cars[-2:]
# Out:
# ['mercedes', 'skoda']

# %%
cars
# Out:
# ['audi', 'bmw', 'audi', 'citroen', 'toyota', 'mercedes', 'skoda']

# %%
cars[0:6:2]
# Out:
# ['audi', 'audi', 'toyota']

# %%
cars[1::2]
# Out:
# ['bmw', 'citroen', 'mercedes']

# %%
cars[::3]
# Out:
# ['audi', 'citroen', 'skoda']

# %%
[0, 0+3, 0+(2*3)]
# Out:
# [0, 3, 6]

# %%
cars
# Out:
# ['audi', 'bmw', 'audi', 'citroen', 'toyota', 'mercedes', 'skoda']

# %%
cars[:]
# Out:
# ['audi', 'bmw', 'audi', 'citroen', 'toyota', 'mercedes', 'skoda']

# %%
cars[::-1]
# Out:
# ['skoda', 'mercedes', 'toyota', 'citroen', 'audi', 'bmw', 'audi']

# %%
text = "Hello there, it's super nice here today!"
text
# Out:
# "Hello there, it's super nice here today!"

# %%
text[:4]
# Out:
# 'Hell'

# %%
text[4:8]
# Out:
# 'o th'

# %%
text[::-1]
# Out:
# "!yadot ereh ecin repus s'ti ,ereht olleH"

# %%
if text[-1] == '!':
  print('Dont yell!')
# Out:
# Dont yell!

# %%
with open('sample_data/girls.txt') as f:
  names_f = f.read()
  names = names_f.splitlines()

# %%
type(names)
# Out:
# list

# %%
len(names)
# Out:
# 99

# %%
names_f
# Out:
# 'Olivia\nEmma\nCharlotte\nAmelia\nAva\nSophia\nIsabella\nMia\nEvelyn\nHarper\nLuna\nCamila\nGianna\nElizabeth\nEleanor\nElla\nAbigail\nSofia\nAvery\nScarlett\nEmily\nAria\nPenelope\nChloe\nLayla\nMila\nNora\nHazel\nMadison\nEllie\nLily\nNova\nIsla\nGrace\nViolet\nAurora\nRiley\nZoey\nWillow\nEmilia\nStella\nZoe\nVictoria\nHannah\nAddison\nLeah\nLucy\nEliana\nIvy\nEverly\nLillian\nPaisley\nElena\nNaomi\nMaya\nNatalie\nKinsley\nDelilah\nClaire\nAudrey\nAaliyah\nRuby\nBrooklyn\nAlice\nAubrey\nAutumn\nLeilani\nSavannah\nValentina\nKennedy\nMadelyn\nJosephine\nBella\nSkylar\nGenesis\nSophie\nHailey\nSadie\nNatalia\nQuinn\nCaroline\nAllison\nGabriella\nAnna\nSerenity\nNevaeh\nCora\nAriana\nEmery\nLydia\nJade\nSarah\nEva\nAdeline\nMadeline\nPiper\nRylee\nAthena\nPeyton\n'
